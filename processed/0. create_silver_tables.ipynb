-- %% [markdown]
-- #### Creating silver (processed) tables
-- 1. Folder
-- 2. Workflow
-- 3. Worklets
-- 4. Tasks
-- 5. Instances
-- 6. Workflow_run

-- %% [markdown]
-- ##Folder Table

-- %%
create or replace table processed.folder(
FOLDER_ID INT,
FOLDER_NAME STRING,
CREATED_DT TIMESTAMP,
UPDATED_DT TIMESTAMP
)
