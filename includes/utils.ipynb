# %% [markdown]
# ### Utils

# %%
from pyspark.sql.functions import current_timestamp

# %%
def add_ingestion_date(df):
    df = df.withColumn("ingestion_date", current_timestamp())
    return df

# %%
def add_insert_date(df):
    df = df.withColumn("created_date", current_timestamp())
    return df
